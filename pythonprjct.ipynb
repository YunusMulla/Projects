# %%
import pandas as pd

# %%
df=pd.read_csv("youtube_dislike_dataset.csv")

# %%
df.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
#statistical analytics
df.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
df.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
newdf=df.dropna()

# %%
newdf.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %%
#changinf data type at published_at
newdf['published_at']=pd.to_datetime(newdf['published_at'])
# Out:
# C:\Users\yunus mulla\AppData\Local\Temp\ipykernel_27160\3782757444.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['published_at']=pd.to_datetime(newdf['published_at'])

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37264 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37264 non-null  object
#  1   title          37264 non-null  object
#  2   channel_id     37264 non-null  object
#  3   channel_title  37264 non-null  object
#  4   published_at   37264 non-null  datetime64[ns]
#  5   view_count     37264 non-null  int64
#  6   likes          37264 non-null  int64
#  7   dislikes       37264 non-null  int64
#  8   comment_count  37264 non-null  int64
#  9   tags           37264 non-null  object
#  10  description    37264 non-null  object
#  11  comments       37264 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 3.7+ MB

# %%
newdf['published_month']=newdf['published_at'].dt.month
# Out:
# C:\Users\yunus mulla\AppData\Local\Temp\ipykernel_27160\2711935987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['published_month']=newdf['published_at'].dt.month

# %%
newdf.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title        published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
#statistical analytics
newdf.describe()
# Out:
#          view_count         likes      dislikes  comment_count  \
# count  3.726400e+04  3.726400e+04  3.726400e+04   3.726400e+04
# mean   5.710821e+06  1.672867e+05  4.996434e+03   9.966953e+03
# std    2.431304e+07  5.384931e+05  3.075194e+04   1.173465e+05
# min    2.036800e+04  2.200000e+01  3.000000e+00   1.000000e+00
# 25%    5.141305e+05  1.331725e+04  2.827500e+02   9.140000e+02
# 50%    1.321860e+06  4.255600e+04  7.980000e+02   2.347000e+03
# 75%    3.674527e+06  1.309665e+05  2.466250e+03   6.212000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07
#
#        published_month
# count     37264.000000
# mean          7.495545
# std           3.306261
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          10.000000
# max          12.000000

# %%
#object analytics
#which shows unique and frequency and top channel
newdf.describe(include='object')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#          tags description                                           comments
# count   37264       37264                                              37264
# unique  28705       35479                                              37264
# top                        Respect to Dortmund fans,must be sad losing hi...
# freq     3808         587                                                  1

# %%
#adding month names column
months={
    1:'jan',
    2:'Feb',
    3:'March',
    4:'April',
    5:'May',
    6:'June',
    7:'July',
    8:'Aug',
    9:'Sep',
    10:'Oct',
    11:'Nov',
    12:'Dec'
}

# %%
newdf['published_month'].map(months)
# Out:
# 0         July
# 1         June
# 2          Sep
# 3        March
# 4          Dec
#          ...
# 37417      Feb
# 37418      jan
# 37419     June
# 37420      Oct
# 37421      May
# Name: published_month, Length: 37264, dtype: object

# %%
newdf.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title        published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
newdf.drop(newdf.columns[[11,12,13]] ,axis=1 ,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27160\2274897.py in <module>
# ----> 1 newdf.drop(newdf.columns[[11,12,13]] ,axis=1 ,inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    5067             key = np.asarray(key, dtype=bool)
#    5068
# -> 5069         result = getitem(key)
#    5070         # Because we ruled out integer above, we always get an arraylike here
#    5071         if result.ndim > 1:
#
# IndexError: index 13 is out of bounds for axis 0 with size 13

# %%
newdf.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title        published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
newdf.drop(newdf.columns[[11]] , axis=1 ,inplace=True)
# Out:
# C:\Users\yunus mulla\AppData\Local\Temp\ipykernel_27160\3507800450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf.drop(newdf.columns[[11]] , axis=1 ,inplace=True)

# %%
newdf.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title        published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
newdf['published_mn']=newdf['published_at'].dt.month
# Out:
# C:\Users\yunus mulla\AppData\Local\Temp\ipykernel_27160\1259865375.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['published_mn']=newdf['published_at'].dt.month

# %%
newdf.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title        published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
newdf1=newdf.sort_values(by='published_mn')

# %%
# Find the number of videos published each month and arrange the months in a decreasing order based on the video count.
df1=newdf.sort_values(by='published_mn').groupby('published_mn').count()

# %%
df1.head(5)
# Out:
#               video_id  title  channel_id  channel_title  published_at  \
# published_mn
# 1                 2099   2099        2099           2099          2099
# 2                 2125   2125        2125           2125          2125
# 3                 2248   2248        2248           2248          2248
# 4                 2119   2119        2119           2119          2119
# 5                 2073   2073        2073           2073          2073
#
#               view_count  likes  dislikes  comment_count  tags  description  \
# published_mn
# 1                   2099   2099      2099           2099  2099         2099
# 2                   2125   2125      2125           2125  2125         2125
# 3                   2248   2248      2248           2248  2248         2248
# 4                   2119   2119      2119           2119  2119         2119
# 5                   2073   2073      2073           2073  2073         2073
#
#               published_month
# published_mn
# ...

# %%
#Find the count of unique video_id, channel_id and channel_title
newdf[['video_id','title','channel_id']].nunique()
# Out:
# video_id      37264
# title         36958
# channel_id    10891
# dtype: int64

# %%
#Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.
df1['view_count'].head(10)
df1['view_count'].tail(10)
# Out:
# published_mn
# 3     2248
# 4     2119
# 5     2073
# 6     2305
# 7     2331
# 8     4250
# 9     4854
# 10    4976
# 11    4821
# 12    3063
# Name: view_count, dtype: int64

# %%
# Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences
newdf=newdf.sort_values(by='published_mn')
max_likes_title=newdf[newdf['likes'] == newdf['likes'].max()]['title'].values[0]

# %%
max_likes_title
# Out:
# "BTS () 'Dynamite' Official MV"

# %%
min_likes_title=newdf[newdf['likes'] == newdf['likes'].min()]['title'].values[0]

# %%
min_likes_title
# Out:
# 'Leading the Charge | Circle K'

# %%
#12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.
max_no_dislike=newdf[newdf['dislikes']==newdf['dislikes'].max()]['title'].values[0]

# %%
min_no_dislike=newdf[newdf['dislikes']==newdf['dislikes'].min()]['title'].values[0]

# %%
min_no_dislike
# Out:
# 'Tims For Good: A Taste Of The Familiar'

# %%
#Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.scatterplot( data=newdf , x= 'view_count' ,y='dislikes')
plt.title("VIEWS VS DISLIKES")
plt.xlabel("Views")
plt.ylabel("Dislikes")
plt.show()

# %%
#Display all the information about the videos that were published in January, and mention the count of videos that were published in January. 
jan_info=newdf.groupby(newdf['published_mn']==1)

# %%
jan_info
